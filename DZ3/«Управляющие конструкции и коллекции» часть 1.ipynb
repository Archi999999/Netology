# %%
#ЗАДАНИЕ 1


word = input('Введите слово: ')
if len(word) % 2 == 0 :
    letter_2 = int(len(word)/2)
    letter_1 = letter_2-1
    print (word[letter_1]+word[letter_2])
else :
    letter = int(len(word)/2)
    print (word[letter])
# Out:
# Введите слово: test
# es

# %%
# ЗАДАНИЕ 2


numbers = []
while 0 not in numbers:
    number = int(input('Введите число: '))
    numbers.append(number)
print (sum(numbers))
# Out:
# Введите число: 1
# Введите число: 9
# Введите число: 5
# Введите число: 4
# Введите число: 1
# Введите число: 0
# 20

# %%
# ЗАДАНИЕ 3

boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
if len(boys) == len(girls):
    couples = zip (sorted(boys), sorted(girls))
    couples = list(couples)
    print ('Идеальные пары: ')
    for couples_1 in couples:
        print (couples_1[0]+' и '+couples_1[1])
else:
    print ('Внимание, кто-то может остаться без пары!')
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# %%
# ЗАДАНИЕ 4

countries_temperature = [
['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
['Germany', [57.2, 55.4, 59, 59, 53.6]],
['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]
print ('Средняя температура в странах:')
for i in countries_temperature:
    print (i[0] ,'-', round((sum(i[1])/len(i[1])-32)/1.8,1,'C')
# Out:
# Средняя температура в странах:
# Thailand - 23.88888888888889 C
# Germany - 13.88888888888889 C
# Russia - 3.888888888888889 C
# Poland - 12.222222222222221 C
